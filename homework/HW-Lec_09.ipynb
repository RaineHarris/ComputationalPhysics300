# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ytext = np.loadtxt("/Users/pulsa/Downloads/HW9/circular.txt")
plt.plot(ytext)
plt.show()

# %%
#apply Fourier Transform to compress file
ytext = np.fft.fftn(text)
print(len(ytext.real))
plt.plot(ytext.real)
#plt.grid()
plt.show()
# Out:
# 501

# %%
#Image of FT
image = np.fft.fftn(ytext).real
plt.imshow(image)
plt.show()

# %%
#comparison of fig sizes using np.savefig
plt.savefig('circular_fft.jpg')
print(np.shape(ytext))
# Out:
# (501, 501)
